         0.10347053],
        [0.02081386, 0.02529298, 0.03950687, 0.04383417, 0.03147825,
         0.08454843, 0.0635888 , 0.05931431, 0.04446232, 0.07684613,
         0.07698387, 0.08771291, 0.0408095 , 0.06652025, 0.07458323,
         0.09342036],
        [0.03580562, 0.0297911 , 0.03794451, 0.03864375, 0.0291836 ,
         0.04433783, 0.04643639, 0.05341729, 0.04864144, 0.05695017,
         0.06465443, 0.07569947, 0.04758675, 0.05315737, 0.06979737,
         0.09695743],
        [0.02300464, 0.02733289, 0.03155006, 0.0404109 , 0.02344518,
         0.04012616, 0.03593934, 0.03554651, 0.04285223, 0.05261369,
         0.05800953, 0.06691874, 0.04563125, 0.05887995, 0.06884519,
         0.08478749]],

       [[0.09025733, 0.08474311, 0.11442767, 0.12748844, 0.07649109,
         0.10165829, 0.11996642, 0.12065242, 0.11805518, 0.1287381 ,
         0.15538904, 0.17032137, 0.14701419, 0.13827161, 0.18278581,
         0.20676665],
        [0.03116325, 0.03073046, 0.0439241 , 0.04225626, 0.03463132,
         0.05913517, 0.05788751, 0.05463574, 0.04824932, 0.06043808,
         0.07065888, 0.07414565, 0.04922715, 0.06165292, 0.08141926,
         0.10011474],
        [0.03459517, 0.04333212, 0.04611156, 0.05254263, 0.02871261,
         0.0349108 , 0.04273293, 0.04149231, 0.04531525, 0.05684619,
         0.06261246, 0.07457149, 0.04160345, 0.05465605, 0.06775474,
         0.09696075],
        [0.03620283, 0.03623734, 0.04259807, 0.04447799, 0.02928486,
         0.04692973, 0.04736894, 0.04966416, 0.05367089, 0.0610604 ,
         0.071238  , 0.07916878, 0.04941986, 0.06064343, 0.07299691,
         0.08823903],
        [0.01833593, 0.02562862, 0.03307006, 0.03882203, 0.02234613,
         0.02946729, 0.03751248, 0.04307808, 0.03172586, 0.04627717,
         0.05483046, 0.07069583, 0.03461615, 0.04274321, 0.05959183,
         0.08450342]]])

# %%
macros_ei = ei_143_168[1]
macros_ei_max = np.zeros((9,5))
for i in range(9):
    for j in range(5):
        macros_ei_max[i,j] = np.nanmax(macros_ei[i,j,:])
plt.imshow(macros_ei_max)
plt.colorbar()
plt.figure()

macros_maxes = np.zeros((16,1))
for i in range(16):
    macros_maxes[i] = np.nanmax(macros_ei[:,:,i])
plt.plot(macros_maxes)

plt.figure()
plt.imshow(ei_143_168[1][:,:,10])
plt.colorbar()

# %%
# load all the data for all neurons ei
connected_ei = np.load("results/connected_ei.npy", allow_pickle=True)

# %%
# Get the maximums for each coarse graining
max_micros_wnan = []
max_macros_wnan = [[] for i in range(16)]

for micros,macros,(i,j) in connected_ei:
    max_micros_wnan.append(np.nanmax(micros))
    max_macro = np.nanmax(macros, axis=(0,1))
    for m in range(len(max_macro)):
        max_macros_wnan[m].append(max_macro[m])

# %%
# get non_nan maxes
max_micros = np.array(max_micros_wnan)
print([i for i, x in enumerate(~np.isnan(max_micros)) if x])
max_micros = max_micros[~np.isnan(max_micros)]

max_macros = [np.array(m_mac) for m_mac in max_macros_wnan]
max_macros = [m_mac[~np.isnan(m_mac)] for m_mac in max_macros]
# Out:
# [0, 1, 2]

# %%
connected_ei
# Out:
# (3,)
